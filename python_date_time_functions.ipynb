# %%
import pandas as pd 
  
    
print("DayNumber Quarter Number")

# Creating the Series 
sr = pd.Series(['2012-10-21 09:30', '2019-7-18 12:30', '2008-02-2 10:30', 
                '2010-4-22 09:25', '2019-11-8 02:22']) 
  
# Creating the index 
idx = ['Day 1        ', 'Day 2        ', 'Day 3        ', 'Day 4        ', 'Day 5        '] 
  
# set the index 
sr.index = idx 
  
# Convert the underlying data to datetime  
sr = pd.to_datetime(sr) 
  
# Print the series 
# print(sr) 


result = sr.dt.quarter 
  
# print the result 
print(result)
# Out:
# DayNumber Quarter Number
# Day 1            4
# Day 2            3
# Day 3            1
# Day 4            2
# Day 5            4
# dtype: int64

# %%
import pandas as pd
import numpy as np
import datetime
import datetime as dt
from numpy import int64

# %%
df=pd.read_csv(r"E:\timepractice.csv",encoding="utf8")

# %%
pwd
# Out:
# 'C:\\Users\\NAMAN AGRAWAL'

# %%
df['year'] = pd.DatetimeIndex(df['Agreed Date']).year
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0

# %%
df['month'] = pd.DatetimeIndex(df['Agreed Date']).month
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0

# %%
df['month_year'] = pd.to_datetime(df['Agreed Date']).dt.to_period('M')
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#   month_year
# 0    2020-04
# 1    2019-10
# 2    2020-01
# 3    2020-02
# 4    2020-02

# %%
df['dob'] = pd.to_datetime(df['Agreed Date'], format='%m/%d/%Y')

# %%
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#   month_year        dob
# 0    2020-04 2020-04-30
# 1    2019-10 2019-10-10
# 2    2020-01 2020-01-15
# 3    2020-02 2020-02-29
# 4    2020-02 2020-02-15

# %%
df['Quarter'] = np.int64((pd.DatetimeIndex(df['Agreed Date']).month)/3)+1

# %%
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#   month_year        dob  Quarter
# 0    2020-04 2020-04-30        2
# 1    2019-10 2019-10-10        4
# 2    2020-01 2020-01-15        1
# 3    2020-02 2020-02-29        1
# 4    2020-02 2020-02-15        1

# %%
df['Week Number'] = pd.to_datetime(df['Agreed Date']).dt.week
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#   month_year        dob  Quarter  Week Number
# 0    2020-04 2020-04-30        2         18.0
# 1    2019-10 2019-10-10        4         41.0
# 2    2020-01 2020-01-15        1          3.0
# 3    2020-02 2020-02-29        1          9.0
# 4    2020-02 2020-02-15        1          7.0

# %%
df['Current Date'] = dt.date.today()

# %%
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#   month_year        dob  Quarter  Week Number Current Date
# 0    2020-04 2020-04-30        2         18.0   2020-03-09
# 1    2019-10 2019-10-10        4         41.0   2020-03-09
# 2    2020-01 2020-01-15        1          3.0   2020-03-09
# 3    2020-02 2020-02-29        1          9.0   2020-03-09
# 4    2020-02 2020-02-15        1          7.0   2020-03-09

# %%
df['Current Month'] = pd.DatetimeIndex(df['Current Date']).month
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#   month_year        dob  Quarter  Week Number Current Date  Current Month
# 0    2020-04 2020-04-30        2         18.0   2020-03-09              3
# 1    2019-10 2019-10-10        4         41.0   2020-03-09              3
# 2    2020-01 2020-01-15        1          3.0   2020-03-09              3
# 3    2020-02 2020-02-29        1          9.0   2020-03-09              3
# 4    2020-02 2020-02-15        1          7.0   2020-03-09              3

# %%
df['Current Year'] = pd.DatetimeIndex(df['Current Date']).year
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#   month_year        dob  Quarter  Week Number Current Date  Current Month  \
# 0    2020-04 2020-04-30        2         18.0   2020-03-09              3
# 1    2019-10 2019-10-10        4         41.0   2020-03-09              3
# 2    2020-01 2020-01-15        1          3.0   2020-03-09              3
# 3    2020-02 2020-02-29        1          9.0   2020-03-09              3
# 4    2020-02 2020-02-15        1          7.0   2020-03-09              3
#
#    Current Year
# 0          2020
# 1          2020
# 2          2020
# 3          2020
# ...

# %%
df['Current Week Number'] = pd.to_datetime(df['Current Date']).dt.week

df['Next Week Number'] = (pd.to_datetime(df['Current Date']).dt.week)+1

df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#   month_year        dob  Quarter  Week Number Current Date  Current Month  \
# 0    2020-04 2020-04-30        2         18.0   2020-03-09              3
# 1    2019-10 2019-10-10        4         41.0   2020-03-09              3
# 2    2020-01 2020-01-15        1          3.0   2020-03-09              3
# 3    2020-02 2020-02-29        1          9.0   2020-03-09              3
# 4    2020-02 2020-02-15        1          7.0   2020-03-09              3
#
#    Current Year  Current Week Number  Next Week Number
# ...

# %%
df.drop(["month_year" ], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#          dob  Quarter  Week Number Current Date  Current Month  Current Year  \
# 0 2020-04-30        2         18.0   2020-03-09              3          2020
# 1 2019-10-10        4         41.0   2020-03-09              3          2020
# 2 2020-01-15        1          3.0   2020-03-09              3          2020
# 3 2020-02-29        1          9.0   2020-03-09              3          2020
# 4 2020-02-15        1          7.0   2020-03-09              3          2020
#
#    Current Week Number  Next Week Number
# ...

# %%
df['Current Quarter'] = np.int64((pd.DatetimeIndex(df['Current Date']).month)/3)

# %%
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#          dob  Quarter  Week Number Current Date  Current Month  Current Year  \
# 0 2020-04-30        2         18.0   2020-03-09              3          2020
# 1 2019-10-10        4         41.0   2020-03-09              3          2020
# 2 2020-01-15        1          3.0   2020-03-09              3          2020
# 3 2020-02-29        1          9.0   2020-03-09              3          2020
# 4 2020-02-15        1          7.0   2020-03-09              3          2020
#
#    Current Week Number  Next Week Number  Current Quarter
# ...

# %%
df['Quarter'] = np.int64((pd.DatetimeIndex(df['Agreed Date']).month)/3)+1

# %%
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#          dob  Quarter  Week Number Current Date  Current Month  Current Year  \
# 0 2020-04-30        2         18.0   2020-03-09              3          2020
# 1 2019-10-10        4         41.0   2020-03-09              3          2020
# 2 2020-01-15        1          3.0   2020-03-09              3          2020
# 3 2020-02-29        1          9.0   2020-03-09              3          2020
# 4 2020-02-15        1          7.0   2020-03-09              3          2020
#
#    Current Week Number  Next Week Number  Current Quarter
# ...

# %%
df.head()
# Out:
#    Qty RRS      Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 0  1.0   C    MCH-630   4/30/2020  9320.0         18.0  2020.0    4.0
# 1  1.0   C  MCH-500-L  10/10/2019  8894.0         41.0  2019.0   10.0
# 2  1.0   B  GEMINI-XL   1/15/2020  9134.0          3.0  2020.0    1.0
# 3  1.0   B  GEMINI-XL   2/29/2020  9301.0          9.0  2020.0    2.0
# 4  1.0   B  GEMINI-XL   2/15/2020  9353.0          7.0  2020.0    2.0
#
#          dob  Quarter  Week Number Current Date  Current Month  Current Year  \
# 0 2020-04-30        2         18.0   2020-03-09              3          2020
# 1 2019-10-10        4         41.0   2020-03-09              3          2020
# 2 2020-01-15        1          3.0   2020-03-09              3          2020
# 3 2020-02-29        1          9.0   2020-03-09              3          2020
# 4 2020-02-15        1          7.0   2020-03-09              3          2020
#
#    Current Week Number  Next Week Number  Current Quarter
# ...

# %%
result = (df['Current Week Number'] == int64(df['Agreed Week']))
df=df.loc[result]
df['Pending Orders']=len(df['S.Ord.'])

# %%
df
# Out:
#      Qty  RRS         Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 6    1.0    B     GEMINI-XL   3/10/2020  9474.0         11.0  2020.0    3.0
# 24   1.0    A        MCV400   3/15/2020  9437.0         11.0  2020.0    3.0
# 29   1.0    A      MCV-400F   3/14/2020  9455.0         11.0  2020.0    3.0
# 36   1.0    A       MCV400F   3/15/2020  9531.0         11.0  2020.0    3.0
# 38   1.0    A  SUPER-WINNER   3/15/2019  7962.0         11.0  2019.0    3.0
# 77   1.0  NaN        MCV450   3/12/2020  9097.0         11.0  2020.0    3.0
# 128  1.0  NaN         M850V   3/14/2020  9470.0         11.0  2020.0    3.0
# 188  1.0  NaN          ACER   3/15/2020  9511.0         11.0  2020.0    3.0
# 189  1.0  NaN          ACER   3/15/2020  9512.0         11.0  2020.0    3.0
# 206  1.0  NaN         M540V   3/15/2020  9478.0         11.0  2020.0    3.0
# 213  1.0  NaN    CMH-500-50   3/14/2020  9535.0         11.0  2020.0    3.0
# ...

# %%
df
# Out:
#      Qty  RRS         Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 6    1.0    B     GEMINI-XL   3/10/2020  9474.0         11.0  2020.0    3.0
# 24   1.0    A        MCV400   3/15/2020  9437.0         11.0  2020.0    3.0
# 29   1.0    A      MCV-400F   3/14/2020  9455.0         11.0  2020.0    3.0
# 36   1.0    A       MCV400F   3/15/2020  9531.0         11.0  2020.0    3.0
# 38   1.0    A  SUPER-WINNER   3/15/2019  7962.0         11.0  2019.0    3.0
# 77   1.0  NaN        MCV450   3/12/2020  9097.0         11.0  2020.0    3.0
# 128  1.0  NaN         M850V   3/14/2020  9470.0         11.0  2020.0    3.0
# 188  1.0  NaN          ACER   3/15/2020  9511.0         11.0  2020.0    3.0
# 189  1.0  NaN          ACER   3/15/2020  9512.0         11.0  2020.0    3.0
# 206  1.0  NaN         M540V   3/15/2020  9478.0         11.0  2020.0    3.0
# 213  1.0  NaN    CMH-500-50   3/14/2020  9535.0         11.0  2020.0    3.0
# ...

# %%
df
# Out:
#      Qty  RRS         Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 6    1.0    B     GEMINI-XL   3/10/2020  9474.0         11.0  2020.0    3.0
# 24   1.0    A        MCV400   3/15/2020  9437.0         11.0  2020.0    3.0
# 29   1.0    A      MCV-400F   3/14/2020  9455.0         11.0  2020.0    3.0
# 36   1.0    A       MCV400F   3/15/2020  9531.0         11.0  2020.0    3.0
# 38   1.0    A  SUPER-WINNER   3/15/2019  7962.0         11.0  2019.0    3.0
# 77   1.0  NaN        MCV450   3/12/2020  9097.0         11.0  2020.0    3.0
# 128  1.0  NaN         M850V   3/14/2020  9470.0         11.0  2020.0    3.0
# 188  1.0  NaN          ACER   3/15/2020  9511.0         11.0  2020.0    3.0
# 189  1.0  NaN          ACER   3/15/2020  9512.0         11.0  2020.0    3.0
# 206  1.0  NaN         M540V   3/15/2020  9478.0         11.0  2020.0    3.0
# 213  1.0  NaN    CMH-500-50   3/14/2020  9535.0         11.0  2020.0    3.0
# ...

# %%
result2 = (df['month'] == df['Current Month'])
df=df.loc[result2]
df['Pending Orders Current Month']=len(df['S.Ord.'])

# %%
df
# Out:
#      Qty  RRS         Model Agreed Date  S.Ord.  Agreed Week    year  month  \
# 6    1.0    B     GEMINI-XL   3/10/2020  9474.0         11.0  2020.0    3.0
# 24   1.0    A        MCV400   3/15/2020  9437.0         11.0  2020.0    3.0
# 29   1.0    A      MCV-400F   3/14/2020  9455.0         11.0  2020.0    3.0
# 36   1.0    A       MCV400F   3/15/2020  9531.0         11.0  2020.0    3.0
# 38   1.0    A  SUPER-WINNER   3/15/2019  7962.0         11.0  2019.0    3.0
# 77   1.0  NaN        MCV450   3/12/2020  9097.0         11.0  2020.0    3.0
# 128  1.0  NaN         M850V   3/14/2020  9470.0         11.0  2020.0    3.0
# 188  1.0  NaN          ACER   3/15/2020  9511.0         11.0  2020.0    3.0
# 189  1.0  NaN          ACER   3/15/2020  9512.0         11.0  2020.0    3.0
# 206  1.0  NaN         M540V   3/15/2020  9478.0         11.0  2020.0    3.0
# 213  1.0  NaN    CMH-500-50   3/14/2020  9535.0         11.0  2020.0    3.0
# ...

# %%
result3 = ((df['Current Month'])+1 == np.int64(df['month']))
df=df.loc[result3]
df['Pending Orders Next Month']=len(df['S.Ord.'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Qty, RRS, Model, Agreed Date, S.Ord., Agreed Week, year, month, dob, Quarter, Week Number, Current Date, Current Month, Current Year, Current Week Number, Next Week Number, Current Quarter, Pending Orders, Pending Orders Current Month, Pending Orders Next Month]
# Index: []

# %%
result4 = ((df['Quarter']) == np.int64(df['Current Quarter'])+1)
df=df.loc[result4]
df['Pending Orders Next Quarter']=len(df['S.Ord.'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Qty, RRS, Model, Agreed Date, S.Ord., Agreed Week, year, month, dob, Quarter, Week Number, Current Date, Current Month, Current Year, Current Week Number, Next Week Number, Current Quarter, Pending Orders, Pending Orders Current Month, Pending Orders Next Month, Pending Orders Next Quarter]
# Index: []
#
# [0 rows x 21 columns]

# %%
result5 = (df['Next Week Number'] == int64(df['Agreed Week']))
df=df.loc[result5]
df['Pending Orders Next Week']=len(df['S.Ord.'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Qty, RRS, Model, Agreed Date, S.Ord., Agreed Week, year, month, dob, Quarter, Week Number, Current Date, Current Month, Current Year, Current Week Number, Next Week Number, Current Quarter, Pending Orders, Pending Orders Current Month, Pending Orders Next Month, Pending Orders Next Quarter, Pending Orders Next Week]
# Index: []
#
# [0 rows x 22 columns]
